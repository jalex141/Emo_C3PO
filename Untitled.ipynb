# %%
import pandas as pd

read_file = pd.read_csv ('./SW_EpisodeVI.txt', sep= " ")

# %%
read_file.to_csv ('./data/SW_EpisodeVI.csv', index=None)

# %%
read_file
# Out:
#      line              character  \
# 0       1        SHUTTLE CAPTAIN
# 1       2  DEATH STAR CONTROLLER
# 2       3        SHUTTLE CAPTAIN
# 3       4                OFFICER
# 4       5               OPERATOR
# ..    ...                    ...
# 669   670                  LANDO
# 670   671                  WEDGE
# 671   672                  LANDO
# 672   673                    HAN
# 673   674               THREEPIO
#
#                                               dialogue
# 0    Command station, this is ST 321. Code Clearanc...
# 1    The security deflector shield will be deactiva...
# 2                         We're starting our approach.
# 3    Inform the commander that Lord Vader's shuttle...
# 4                                            Yes, sir.
# ..                                                 ...
# 669       Wedge, I don't think we're going to make it.
# 670        You'll make it. Just follow me Gold Leader.
# 671  I promised to return his ship without a scratc...
# ...
